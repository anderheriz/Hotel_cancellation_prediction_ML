# %% [markdown]
# # 01 - Fuentes y definicion del problema
#
# Este notebook documenta la fuente de datos y define el problema de Machine Learning. El analisis detallado, limpieza, nulos, duplicados, outliers y feature engineering se desarrollan en `02_LimpiezaEDA.ipynb`.

# %% [markdown]
# ## 1. Fuente de datos
#
# - **Fuente:** Kaggle
# - **Dataset:** Hotel Booking Demand
# - **URL:** https://www.kaggle.com/datasets/jessemostipak/hotel-booking-demand
# - **Archivo local:** `data/raw/hotel_bookings.csv`
#
# El dataset contiene reservas hoteleras de dos tipos de hotel: `City Hotel` y `Resort Hotel`.

# %%
import pandas as pd

DATA_PATH = "../data/raw/hotel_bookings.csv"
df = pd.read_csv(DATA_PATH)
df.head()

# %% [markdown]
# ## 2. Tamano del dataset
#
# El enunciado pide un minimo de **1.000 registros** y **10 campos**. Este dataset cumple de sobra ese requisito.

# %%
print(f"Filas: {df.shape[0]:,}".replace(",", "."))
print(f"Columnas: {df.shape[1]}")
